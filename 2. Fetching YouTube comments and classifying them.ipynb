# %% [markdown]
# # Fetching YouTube comments and classifying them

# %% [markdown]
# In this notebook we fetch comments from YouTube and classify them using the model trained in the previous notebook."

# %% [markdown]
# See this page for a handy way of setting up access to the YouTube data API: [https://python.gotrained.com/youtube-api-extracting-comments/](https://python.gotrained.com/youtube-api-extracting-comments/)
#
# YouTube API
# [https://developers.google.com/youtube/v3/docs/commentThreads/list](https://developers.google.com/youtube/v3/docs/commentThreads/list)

# %%
# !pip install google-api-python-client
# !pip install google-auth google-auth-oauthlib google-auth-httplib2
# Out:
# Looking in indexes: https://packages.dns.ad.zopa.com/artifactory/api/pypi/pypi-python2711-virtual/simple/
# Requirement already satisfied: google-api-python-client in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (1.8.0)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from google-api-python-client) (3.0.1)
# Requirement already satisfied: google-auth>=1.4.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from google-api-python-client) (1.11.3)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from google-api-python-client) (0.17.0)
# Requirement already satisfied: six<2dev,>=1.6.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from google-api-python-client) (1.11.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from google-api-python-client) (0.0.3)
# Requirement already satisfied: google-api-core<2dev,>=1.13.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from google-api-python-client) (1.16.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from google-auth>=1.4.1->google-api-python-client) (4.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from google-auth>=1.4.1->google-api-python-client) (0.2.8)
# Requirement already satisfied: setuptools>=40.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from google-auth>=1.4.1->google-api-python-client) (46.1.1)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from google-auth>=1.4.1->google-api-python-client) (3.4.2)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from google-api-core<2dev,>=1.13.0->google-api-python-client) (1.51.0)
# Requirement already satisfied: pytz in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from google-api-core<2dev,>=1.13.0->google-api-python-client) (2018.4)
# Requirement already satisfied: protobuf>=3.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from google-api-core<2dev,>=1.13.0->google-api-python-client) (3.6.1)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from google-api-core<2dev,>=1.13.0->google-api-python-client) (2.20.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->google-api-python-client) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.13.0->google-api-python-client) (2019.11.28)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.13.0->google-api-python-client) (1.23)
# Requirement already satisfied: idna<2.8,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.13.0->google-api-python-client) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.13.0->google-api-python-client) (3.0.4)
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Looking in indexes: https://packages.dns.ad.zopa.com/artifactory/api/pypi/pypi-python2711-virtual/simple/
# Requirement already satisfied: google-auth in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (1.11.3)
# Collecting google-auth-oauthlib
#   Downloading https://packages.dns.ad.zopa.com/artifactory/api/pypi/pypi-python2711-virtual/packages/7b/b8/88def36e74bee9fce511c9519571f4e485e890093ab7442284f4ffaef60b/google_auth_oauthlib-0.4.1-py2.py3-none-any.whl
# Requirement already satisfied: google-auth-httplib2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (0.0.3)
# Requirement already satisfied: setuptools>=40.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from google-auth) (46.1.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from google-auth) (4.0.0)
# Requirement already satisfied: six>=1.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from google-auth) (1.11.0)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from google-auth) (3.4.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from google-auth) (0.2.8)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib)
#   Downloading https://packages.dns.ad.zopa.com/artifactory/api/pypi/pypi-python2711-virtual/packages/a3/12/b92740d845ab62ea4edf04d2f4164d82532b5a0b03836d4d4e71c6f3d379/requests_oauthlib-1.3.0-py2.py3-none-any.whl
# Requirement already satisfied: httplib2>=0.9.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from google-auth-httplib2) (0.17.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from rsa<4.1,>=3.1.4->google-auth) (0.4.8)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib)
#   Downloading https://packages.dns.ad.zopa.com/artifactory/api/pypi/pypi-python2711-virtual/packages/05/57/ce2e7a8fa7c0afb54a0581b14a65b56e62b5759dbc98e80627142b8a3704/oauthlib-3.1.0-py2.py3-none-any.whl (147kB)
#     100% |████████████████████████████████| 153kB 101.6MB/s ta 0:00:01
# Requirement already satisfied: requests>=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.20.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (1.23)
# Requirement already satisfied: idna<2.8,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.6)
# Installing collected packages: oauthlib, requests-oauthlib, google-auth-oauthlib
# Successfully installed google-auth-oauthlib-0.4.1 oauthlib-3.1.0 requests-oauthlib-1.3.0
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import os
import pickle

# %% [markdown]
# Enter my personal YouTube client keys.

# %%
CLIENT_SECRETS_FILE = 'client_secret_1049876915637-7ia95c7rg5teak6crcuodies22keluuh.apps.googleusercontent.com.json'

# %% [markdown]
# Specify the scope of this application.

# %%
SCOPES = ['https://www.googleapis.com/auth/youtube.force-ssl']
API_SERVICE_NAME = 'youtube'
API_VERSION = 'v3'

# %%
import google.oauth2.credentials

from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google_auth_oauthlib.flow import InstalledAppFlow

def get_authenticated_service():
    credentials = None
    if os.path.exists('token.pickle'):
        with open('token.pickle', 'rb') as token:
            credentials = pickle.load(token)
    #  Check if the credentials are invalid or do not exist
    if not credentials or not credentials.valid:
        # Check if the credentials have expired
        if credentials and credentials.expired and credentials.refresh_token:
            credentials.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                CLIENT_SECRETS_FILE, SCOPES)
            credentials = flow.run_console()
 
        # Save the credentials for the next run
        with open('token.pickle', 'wb') as token:
            pickle.dump(credentials, token)
 
    return build(API_SERVICE_NAME, API_VERSION, credentials = credentials)

# %%
# When running locally, disable OAuthlib's HTTPs verification. When
# running in production *do not* leave this option enabled.
os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'
service = get_authenticated_service()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=1049876915637-7ia95c7rg5teak6crcuodies22keluuh.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fyoutube.force-ssl&state=xfvM85KQNj7cVxvpWQx3PKb5KNJzSG&prompt=consent&access_type=offline
# Enter the authorization code:  4/xwGsBXx6iibf8BNxTJaIiykthOk2qKgbNzMStmECaRbNTW0JDqqFFa0

# %% [markdown]
# ### Search videos and fetch comments

# %%
import csv


def get_video_comments(service, **kwargs):
    comments = []
    results = service.commentThreads().list(**kwargs).execute()

    while results:
        for item in results['items']:
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            comments.append(comment)

        if 'nextPageToken' in results:
            kwargs['pageToken'] = results['nextPageToken']
            results = service.commentThreads().list(**kwargs).execute()
        else:
            break

    return comments

        
def search_videos_by_keyword(service, **kwargs):
    results = get_videos(service, **kwargs)
    final_result = []
    for item in results:
        title = item['snippet']['title']
        video_id = item['id']['videoId']
        comments = get_video_comments(service, part='snippet', videoId=video_id, textFormat='plainText')
        final_result.extend([(video_id, title, comment) for comment in comments])
    
    return final_result


def write_to_csv(comments):
    with open('comments.csv', 'w') as comments_file:
        comments_writer = csv.writer(comments_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        comments_writer.writerow(['Video ID', 'Title', 'Comment'])
        for row in comments:
            comments_writer.writerow(list(row))

# %%
keyword = input('Enter a keyword: ')
comments = search_videos_by_keyword(service, q=keyword, part='id,snippet', eventType='completed', type='video')
# Out:
# Enter a keyword:  town of salem

# %%
len(comments)
# Out:
# 2321

# %%
import pandas as pd

comments_data = pd.DataFrame({
    'title': [comment[1] for comment in comments],
    'comment': [comment[2] for comment in comments]
})
comments_data
# Out:
#                                                   title  \
# 0     TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# 1     TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# 2     TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# 3     TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# 4     TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# 5     TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# 6     TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# 7     TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# 8     TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# 9     TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# 10    TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# 11    TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# 12    TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# 13    TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# 14    TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# 15    TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# 16    TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# 17    TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# 18    TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# 19    TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# 20    TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# 21    TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# 22    TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# 23    TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# 24    TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# 25    TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# 26    TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# 27    TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# 28    TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# 29    TROLLING PLAYERS - TOWN OF SALEM MYSTERY GAME ...
# ...                                                 ...
# 2291  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
# 2292  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
# 2293  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
# 2294  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
# 2295  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
# 2296  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
# 2297  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
# 2298  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
# 2299  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
# 2300  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
# 2301  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
# 2302  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
# 2303  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
# 2304  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
# 2305  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
# 2306  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
# 2307  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
# 2308  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
# 2309  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
# 2310  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
# 2311  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
# 2312  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
# 2313  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
# 2314  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
# 2315  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
# 2316  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
# 2317  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
# 2318  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
# 2319  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
# 2320  WHO IS THE CRIMINAL IN THE GAME? - TOWN OF SAL...
#
#                                                 comment
# 0     When you realize that Jerome’s GA target tried...
# 1     Wait...\nIn ACE ToS vids, his name is JeromeAS...
# 2     I had those exact gumby toys. With the pony i ...
# 3                   Your stupid the mayor left the game
# 4     Question...\n\n\nhow can hades the god of the ...
# 5                                         59:59 really?
# 6     Here are some sample names person in comments ...
# 7     Your target as GA was trying to kill you but t...
# 8                                                     1
# 9                                                     1
# 10    1111111111111111111666111111111111111111111111...
# 11                          Another one and another one
# 12                                              9:59:59
# 13               In the first game it's town of friends
# 14    1111111111111111111111111111111111111111111111...
# 15    The guy he was protecting attacked his own gua...
# 16    I wonder when he will realize stream snipers c...
# 17                                     Steve is my mood
# 18    Rlly you worried about stream snipers then you...
# 19                                                59.59
# 20                             I think Jerome is Cheese
# 21                                                Hello
# 22                              What is stream sniping?
# 23                                               Cheese
# 24    Hey jerome i wanted to tell u that u make my d...
# 25                                                    1
# 26    What is fun well fun is it’s kinda like here l...
# 27                                       The mayor left
# 28    Jerome you can’t revive someone who is stoned ...
# 29    I know I am late but did anyone else notice th...
# ...                                                 ...
# 2291                                               more
# 2292                                               More
# 2293  In the first round w was the medium but you ke...
# 2294                                       amazing game
# 2295                                                 Hi
# 2296                                    More pls jerome
# 2297  PPPPPPPPLLLLLLLLLLLLLLLLLEEEEEEEEEEEAAAAAAAAAA...
# 2298                             Always block your name
# 2299  How does jerome not realize that sheriff and i...
# 2300                                  play more of this
# 2301  missed the stream so i came to youtube were i ...
# 2302  Play ranked practice or one of the chaos modes...
# 2303  Jerome has no idea how to play this game and i...
# 2304               I'm always here when the stream ends
# 2305                                                Moo
# 2306  I would like to point out that Jerome was SHER...
# 2307                                   i love this game
# 2308        Jerome can you also do troll parkour please
# 2309                                   Lol the bio... 😂
# 2310               Jerome please do more of this please
# 2311                                                 Hi
# 2312                                            Do more
# 2313                   Never trust an edited comment...
# 2314  Can you get a grave me as a scribe you back an...
# 2315                                              First
# 2316  I think you should do this on you r other channel
# 2317  Jerome do way more of this game, I love it and...
# 2318                               2,000 something like
# 2319                                             Second
# 2320                                              First
#
# [2321 rows x 2 columns]

# %%
import pickle
with open('models/models_dict.pkl', 'rb') as f:
    models_dict = pickle.load(f)

# %%
word_vectorizer = models_dict['word_vectorizer']
char_vectorizer = models_dict['char_vectorizer']
models = models_dict['models']

# %%
from scipy.sparse import hstack

def classify_comment(comment, word_vectorizer, char_vectorizer, models, probability=False, return_df=False):
    """
    :param comment: a string, the raw data to score
    """
    word_features = word_vectorizer.transform([comment])
    char_features = char_vectorizer.transform([comment])
    combined_features = hstack([char_features, word_features])
    
    prediction = {}
    for class_name, model in models.items():
        if probability:
            # Take the positive class probability prediction
            class_prediction = model.predict_proba(combined_features)[0][1]
        else:
            class_prediction = model.predict(combined_features)[0]
            
        prediction[class_name] = [class_prediction]
    
    if return_df:
        return  pd.DataFrame(prediction)
    else:
        return prediction

# %%
comments_data.loc[3, 'comment']
# Out:
# 'Your stupid the mayor left the game'

# %%
classify_comment(comments_data.loc[3, 'comment'], word_vectorizer, char_vectorizer, models, return_df=True)
# Out:
#    toxic  severe_toxic  obscene  threat  insult  identity_hate
# 0      1             0        0       0       0              0
